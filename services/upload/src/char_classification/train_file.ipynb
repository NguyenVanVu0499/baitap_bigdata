# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My\ Drive/Colab\ Notebooks/License-Plate-Recognition/src/char_classification
# Out:
# /content/drive/My Drive/Colab Notebooks/License-Plate-Recognition/src/char_classification

# %%
# !ls /content/drive/My\ Drive/Colab\ Notebooks/License-Plate-Recognition/src/char_classification/data
# Out:
# alphas.npy  categorized  digits.npy

# %%
# !unzip K.zip -d ./

# %%
# !nvidia-smi
# Out:
# Tue Oct 12 09:32:26 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.74       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P8    29W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !python3 create_data.py

# %%
from model import CNN_Model

model = CNN_Model(trainable=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 28, 28, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 26, 26, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 11, 11, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# ...

# %%
model.train()

# %%
# %cd /content/drive/My\ Drive/Colab\ Notebooks/License-Plate-Recognition/src/char_classification/data/categorized/
# Out:
# /content/drive/My Drive/Colab Notebooks/License-Plate-Recognition/src/char_classification/data/categorized

# %%
# !unzip digits.zip -d ./digits

# %%
# !ls
# Out:
# digits	GreenParking

# %%
# !unzip alphas.zip -d ./alphas
# Out:
# unzip:  cannot find or open alphas.zip, alphas.zip.zip or alphas.zip.ZIP.

# %%
# !python3 main.py --image_path=samples/1.jpg
# Out:
# Traceback (most recent call last):
#   File "main.py", line 27, in <module>
#     model = E2E()
#   File "/content/drive/My Drive/Colab Notebooks/License-Plate-Recognition/src/lp_recognition.py", line 27, in __init__
#     self.detectLP = detectNumberPlate(LP_DETECTION_CFG['classes_path'], LP_DETECTION_CFG['config_path'], LP_DETECTION_CFG['weight_path'])
#   File "/content/drive/My Drive/Colab Notebooks/License-Plate-Recognition/src/lp_detection/detect.py", line 14, in __init__
#     self.model = cv2.dnn.readNet(model=self.weight_path, config=self.cfg_path)
# cv2.error: OpenCV(4.1.2) /io/opencv/modules/dnn/src/darknet/darknet_importer.cpp:207: error: (-212:Parsing error) Failed to parse NetParameter file: ./src/lp_detection/cfg/yolov3-tiny.cfg in function 'readNetFromDarknet'

# %%
# !nvidia-smi
