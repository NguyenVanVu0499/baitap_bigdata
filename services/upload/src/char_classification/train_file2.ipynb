# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My\ Drive/Colab\ Notebooks/License-Plate-Recognition/src/char_classification/
# Out:
# /content/drive/My Drive/Colab Notebooks/License-Plate-Recognition/src/char_classification

# %%
# %cd /content/drive/My\ Drive/Colab\ Notebooks/License-Plate-Recognition/src/char_classification/data/categorized/alphas/W
# Out:
# /content/drive/My Drive/Colab Notebooks/License-Plate-Recognition/src/char_classification/data/categorized/alphas/W

# %%
# !ls /content/drive/My\ Drive/Colab\ Notebooks/License-Plate-Recognition/src/char_classification/data/categorized/alphas/W
# Out:
# ^C

# %%
# !nvidia-smi
# Out:
# Thu Oct 14 07:59:50 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.74       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8    27W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !ls
# Out:
# D.zip

# %%
from model import CNN_Model

model = CNN_Model(trainable=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 28, 28, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 26, 26, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 11, 11, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# ...

# %%
model.train()
# Out:
# Training......
# Epoch 1/50
# 1519/1519 [==============================] - 61s 20ms/step - loss: 0.7016 - acc: 0.8043 - val_loss: 0.1554 - val_acc: 0.9548
# Epoch 2/50
# 1519/1519 [==============================] - 30s 20ms/step - loss: 0.2020 - acc: 0.9404 - val_loss: 0.0918 - val_acc: 0.9743
# Epoch 3/50
# 1519/1519 [==============================] - 30s 20ms/step - loss: 0.1501 - acc: 0.9550 - val_loss: 0.0689 - val_acc: 0.9800
# Epoch 4/50
# 1519/1519 [==============================] - 30s 20ms/step - loss: 0.1243 - acc: 0.9631 - val_loss: 0.0555 - val_acc: 0.9838
# Epoch 5/50
# 1519/1519 [==============================] - 30s 20ms/step - loss: 0.1120 - acc: 0.9664 - val_loss: 0.0506 - val_acc: 0.9846
# Epoch 6/50
# 1519/1519 [==============================] - 30s 20ms/step - loss: 0.0983 - acc: 0.9707 - val_loss: 0.0423 - val_acc: 0.9870
# Epoch 7/50
# 1519/1519 [==============================] - 30s 20ms/step - loss: 0.0935 - acc: 0.9723 - val_loss: 0.0404 - val_acc: 0.9872
# ...
